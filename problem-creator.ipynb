# %% [markdown]
# Copyright **`(c)`** 2025 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free under certain conditions — see the [`license`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %% [markdown]
# # Import and setup

# %%
from itertools import product, combinations
import numpy as np
import networkx as nx
import heapq
import pandas as pd
import time
from typing import Dict, List, Tuple, Optional

# %% [markdown]
# # Problem generator
#
# ``
# create_problem(size, density, negative_values, noise_level, seed) -> (problem_matrix, node_coordinates)
# ``
#
# Generates random weighted directed graph as adjacency matrix.

# %%
def create_problem(
    size: int,
    *,
    density: float = 1.0,
    negative_values: bool = False,
    noise_level: float = 0.0,
    seed: int = 42,
) -> Tuple[np.ndarray, np.ndarray]:

    rng = np.random.default_rng(seed)
    map = rng.random(size=(size, 2))
    problem = rng.random((size, size))
    if negative_values:
        problem = problem * 2 - 1
    problem *= noise_level
    for a, b in product(range(size), repeat=2):
        if rng.random() < density:
            problem[a, b] += np.sqrt(
                np.square(map[a, 0] - map[b, 0]) + np.square(map[a, 1] - map[b, 1])
            )
        else:
            problem[a, b] = np.inf
    np.fill_diagonal(problem, 0)
    return (problem * 1_000).round(), map

# %% [markdown]
# # Utility functions
#
# ``python
# path_reconstruct(predecessors, current) -> path
# ``
#
# Reconstructs path by backtracking through predecessor map until reaching start node (where predecessor is None).
#
# ``python
# has_negative_edges(graph) -> bool
# ``
#
# Iterates through all edges checking if any weight is negative. Used to determine which algorithm to apply.

# %%
def path_reconstruct(predecessors: Dict[int, Optional[int]], current: int) -> List[int]:

    path = []
    while current is not None:
        path.append(current)
        current = predecessors[current]
    path.reverse()
    return path

def has_negative_edges(graph: nx.DiGraph) -> bool:

    for u, v in graph.edges():
        if graph[u][v].get('weight', 1) < 0:
            return True
    return False

# %% [markdown]
# # Algorithms

# %% [markdown]
# ## Dijkstra
#
# `dijkstra(graph, start) -> (distances, predecessors)`
#
# Single-source shortest path using priority queue. Returns distances from start to all nodes and predecessor map.
#
# **Complexity**: O((V + E) log V) with priority queue
# **Limitation**: Does not work with negative weights

# %%
def dijkstra(graph: nx.DiGraph, start: int) -> Tuple[Dict[int, float], Dict[int, Optional[int]]]:

    distances = {node: np.inf for node in graph.nodes}
    predecessors = {node: None for node in graph.nodes}
    distances[start] = 0

    queue = [(0, start)]
    visited = set()

    while queue:
        current_distance, current = heapq.heappop(queue)

        if current in visited:
            continue
        visited.add(current)

        for neighbor in graph.successors(current):
            edge_weight = graph[current][neighbor].get('weight', 1)
            tentative_distance = current_distance + edge_weight

            if tentative_distance < distances[neighbor]:
                distances[neighbor] = tentative_distance
                predecessors[neighbor] = current
                heapq.heappush(queue, (tentative_distance, neighbor))

    return distances, predecessors

# %% [markdown]
# ## A* (A-star)
#
# `a_star(graph, start, goal, coords_map) -> (path, distance)`
#
# A* search from start to goal using f(n) = g(n) + h(n). Returns optimal path and its cost.
#
# **Heuristic**: Euclidean distance between nodes
# **Complexity**: O(E) best case, O(b^d) worst case
# **Limitation**: Does not work with negative weights

# %%
def heuristic(node: int, goal: int, coords_map: np.ndarray) -> float:

    dist = np.linalg.norm(coords_map[node] - coords_map[goal])
    return np.round(dist * 1_000)

def a_star(graph: nx.DiGraph, start: int, goal: int, coords_map: np.ndarray) -> Tuple[Optional[List[int]], float]:

    if start == goal:
        return [start], 0
    
    counter = 0
    to_visit = [(heuristic(start, goal, coords_map), counter, start)]
    counter += 1

    predecessors = {}
    g_scores = {start: 0}
    visited = set()

    while to_visit:
        _, _, current = heapq.heappop(to_visit)

        if current in visited:
            continue
        visited.add(current)

        if current == goal:
            path = []
            node = current
            while node in predecessors:
                path.append(node)
                node = predecessors[node]
            path.append(start)
            path.reverse()
            return path, g_scores[goal]
        
        for neighbor in graph.successors(current):
            if neighbor in visited:
                continue
            
            edge_weight = graph[current][neighbor].get('weight', 1)
            tentative_g_score = g_scores[current] + edge_weight

            if neighbor not in g_scores or tentative_g_score < g_scores[neighbor]:
                predecessors[neighbor] = current
                g_scores[neighbor] = tentative_g_score
                f_score = tentative_g_score + heuristic(neighbor, goal, coords_map)
                heapq.heappush(to_visit, (f_score, counter, neighbor))
                counter += 1

    return None, np.inf

# %% [markdown]
# ## Bellman Ford
#
# `bellman_ford(graph, start) -> (distances, predecessors)`
#
# More general algorithm that handles negative weights and detects negative cycles. Single-source shortest path using edge relaxation. Returns None if negative cycle detected.
#
# **Complexity**: O(V * E)
# **Advantage**: Works with negative weights, detects negative cycles

# %%
def bellman_ford(graph: nx.DiGraph, start: int) -> Tuple[Optional[Dict[int, float]], Optional[Dict[int, Optional[int]]]]:

    distances = {node: np.inf for node in graph.nodes}
    predecessors = {node: None for node in graph.nodes}
    distances[start] = 0

    for _ in range(len(graph.nodes) - 1):
        for u, v in graph.edges():
            weight = graph[u][v].get('weight', 1)
            if distances[u] + weight < distances[v]:
                distances[v] = distances[u] + weight
                predecessors[v] = u

    for u, v in graph.edges():
        weight = graph[u][v].get('weight', 1)
        if distances[u] + weight < distances[v]:
            return None, None
    
    return distances, predecessors

# %% [markdown]
# # All-Pairs Shortest Paths
#
# Functions that run algorithms for all pairs of nodes
#
# `all_pairs_dijkstra(graph) -> (all_distances, all_paths)`
#
# Runs Dijkstra from each node as source. Returns lists of distance and path dictionaries.
#
# `all_pairs_astar(graph, coords_map) -> (all_distances, all_paths)`
#
# Runs A* for all pairs of nodes. Requires node coordinates for heuristic.
#
# `all_pairs_bellman_ford(graph) -> (all_distances, all_paths)`
#
# Runs Bellman-Ford from each node as source. Handles negative weights.

# %%
def all_pairs_dijkstra(graph: nx.DiGraph) -> Tuple[List[Dict], List[Dict]]:

    all_paths = []
    all_distances = []
    
    for source in graph.nodes:
        distances, predecessors = dijkstra(graph, source)
        source_paths = {}
        source_distances = {}
        
        for target in graph.nodes:
            if distances[target] != np.inf:
                path = path_reconstruct(predecessors, target)
                source_paths[target] = path
                source_distances[target] = distances[target]
            else:
                source_paths[target] = None
                source_distances[target] = np.inf
        
        all_distances.append(source_distances)
        all_paths.append(source_paths)
        
    return all_distances, all_paths

def all_pairs_astar(graph: nx.DiGraph, coords_map: np.ndarray) -> Tuple[List[Dict], List[Dict]]:

    all_paths = []
    all_distances = []
    
    for source in graph.nodes:
        source_paths = {}
        source_distances = {}
        
        for target in graph.nodes:
            path, distance = a_star(graph, source, target, coords_map)
            source_paths[target] = path
            source_distances[target] = distance
        
        all_distances.append(source_distances)
        all_paths.append(source_paths)
        
    return all_distances, all_paths

def all_pairs_bellman_ford(graph: nx.DiGraph) -> Tuple[List[Dict], List[Dict]]:

    all_paths = []
    all_distances = []
    
    for source in graph.nodes:
        distances, predecessors = bellman_ford(graph, source)

        if distances is None:
            source_paths = {target: None for target in graph.nodes}
            source_distances = {target: None for target in graph.nodes}
        else:
            source_paths = {}
            source_distances = {}
            
            for target in graph.nodes:
                if distances[target] != np.inf:
                    path = path_reconstruct(predecessors, target)
                    source_paths[target] = path
                    source_distances[target] = distances[target]
                else:
                    source_paths[target] = None
                    source_distances[target] = np.inf
        
        all_distances.append(source_distances)
        all_paths.append(source_paths)
        
    return all_distances, all_paths

# %% [markdown]
# # Problem Execution
#
# `run_problem(size, density, noise_level, negative_values, save_results)`
#
# Solves a problem with all appropriate algorithms. Automatically chooses Bellman-Ford if negative edges exist, otherwise runs Dijkstra and A*. Saves results to CSV.

# %%
def run_problem(size: int, density: float, noise_level: float, negative_values: bool, save_results: bool = True):

    print(f"Running: size={size}, density={density}, noise={noise_level}, neg={negative_values}")
    
    problem, coords_map = create_problem(
        size,
        density=density,
        noise_level=noise_level,
        negative_values=negative_values,
    )

    masked = np.ma.masked_array(problem, mask=np.isinf(problem))
    G = nx.from_numpy_array(masked, create_using=nx.DiGraph)

    has_neg_edges = has_negative_edges(G)

    result_for_csv = []
    
    if not has_neg_edges:
        print("  Running Dijkstra...")
        start_time = time.time()
        dijkstra_distances, dijkstra_paths = all_pairs_dijkstra(G)
        dijkstra_time = time.time() - start_time
        
        print("  Running A*...")
        start_time = time.time()
        astar_distances, astar_paths = all_pairs_astar(G, coords_map)
        astar_time = time.time() - start_time
        
        bford_distances, bford_paths = None, None
        bford_time = None
        
        print(f"  Dijkstra: {dijkstra_time:.4f}s | A*: {astar_time:.4f}s")
    else:
        print("  Running Bellman-Ford (negative edges detected)...")
        start_time = time.time()
        bford_distances, bford_paths = all_pairs_bellman_ford(G)
        bford_time = time.time() - start_time
        
        dijkstra_distances, dijkstra_paths = None, None
        astar_distances, astar_paths = None, None
        
        print(f"  Bellman-Ford: {bford_time:.4f}s")

    if save_results:
        for source in range(size):
            for target in range(size):
                result_for_csv.append({
                    "source": source,
                    "target": target,
                    "dijkstra_distance": dijkstra_distances[source][target] if not has_neg_edges else None,
                    "astar_distance": astar_distances[source][target] if not has_neg_edges else None,
                    "bford_distance": bford_distances[source][target] if has_neg_edges else None,
                    "dijkstra_path": str(dijkstra_paths[source][target]) if not has_neg_edges else None,
                    "astar_path": str(astar_paths[source][target]) if not has_neg_edges else None,
                    "bford_path": str(bford_paths[source][target]) if has_neg_edges else None,
                })
        
        df = pd.DataFrame(result_for_csv)
        filename = f"ResultsCSV/metrics_size{size}_density{density}_noise{noise_level}_neg{negative_values}.csv"
        df.to_csv(filename, index=False)
        print(f"  Saved: {filename}\n")

# %% [markdown]
# # Configurations
#
# **sizes**: Dimensions of test problems (10 to 1000 nodes)
#
# **densities**: Graph sparsity levels (0.2 = sparse, 1.0 = complete graph)
#
# **noise_levels**: Perturbation applied to base Euclidean distances
#
# **negative_values_options**: Toggle negative edge weights

# %%
sizes = [10, 20, 50, 100, 200, 500, 1000]
densities = [0.2, 0.5, 0.8, 1.0]
noise_levels = [0.0, 0.1, 0.5, 0.8]
negative_values_options = [False, True]

# %%
print("=" * 80)
print("All tests execution")
print("=" * 80 + "\n")

total_configs = len(sizes) * len(densities) * len(noise_levels) * len(negative_values_options)
current = 0

for size in sizes:
    for density in densities:
        for noise_level in noise_levels:
            for negative_values in negative_values_options:
                current += 1
                print(f"[{current}/{total_configs}]", end=" ")
                run_problem(size, density, noise_level, negative_values)

print("=" * 80)
print("Execution completed")
print("=" * 80)
# Out:
# ================================================================================
# All tests execution
# ================================================================================
#
# [1/224] Running: size=10, density=0.2, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0031s
#   Saved: ResultsCSV/metrics_size10_density0.2_noise0.0_negFalse.csv
#
# [2/224] Running: size=10, density=0.2, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0001s | A*: 0.0026s
#   Saved: ResultsCSV/metrics_size10_density0.2_noise0.0_negTrue.csv
#
# [3/224] Running: size=10, density=0.2, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0027s
#   Saved: ResultsCSV/metrics_size10_density0.2_noise0.1_negFalse.csv
#
# [4/224] Running: size=10, density=0.2, noise=0.1, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0039s
#   Saved: ResultsCSV/metrics_size10_density0.2_noise0.1_negTrue.csv
#
# [5/224] Running: size=10, density=0.2, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0001s | A*: 0.0025s
#   Saved: ResultsCSV/metrics_size10_density0.2_noise0.5_negFalse.csv
#
# [6/224] Running: size=10, density=0.2, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0006s
#   Saved: ResultsCSV/metrics_size10_density0.2_noise0.5_negTrue.csv
#
# [7/224] Running: size=10, density=0.2, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0001s | A*: 0.0028s
#   Saved: ResultsCSV/metrics_size10_density0.2_noise0.8_negFalse.csv
#
# [8/224] Running: size=10, density=0.2, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0008s
#   Saved: ResultsCSV/metrics_size10_density0.2_noise0.8_negTrue.csv
#
# [9/224] Running: size=10, density=0.5, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0029s
#   Saved: ResultsCSV/metrics_size10_density0.5_noise0.0_negFalse.csv
#
# [10/224] Running: size=10, density=0.5, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0028s
#   Saved: ResultsCSV/metrics_size10_density0.5_noise0.0_negTrue.csv
#
# [11/224] Running: size=10, density=0.5, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0029s
#   Saved: ResultsCSV/metrics_size10_density0.5_noise0.1_negFalse.csv
#
# [12/224] Running: size=10, density=0.5, noise=0.1, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0028s
#   Saved: ResultsCSV/metrics_size10_density0.5_noise0.1_negTrue.csv
#
# [13/224] Running: size=10, density=0.5, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0031s
#   Saved: ResultsCSV/metrics_size10_density0.5_noise0.5_negFalse.csv
#
# [14/224] Running: size=10, density=0.5, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0012s
#   Saved: ResultsCSV/metrics_size10_density0.5_noise0.5_negTrue.csv
#
# [15/224] Running: size=10, density=0.5, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0032s
#   Saved: ResultsCSV/metrics_size10_density0.5_noise0.8_negFalse.csv
#
# [16/224] Running: size=10, density=0.5, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0012s
#   Saved: ResultsCSV/metrics_size10_density0.5_noise0.8_negTrue.csv
#
# [17/224] Running: size=10, density=0.8, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0031s
#   Saved: ResultsCSV/metrics_size10_density0.8_noise0.0_negFalse.csv
#
# [18/224] Running: size=10, density=0.8, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0031s
#   Saved: ResultsCSV/metrics_size10_density0.8_noise0.0_negTrue.csv
#
# [19/224] Running: size=10, density=0.8, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0032s
#   Saved: ResultsCSV/metrics_size10_density0.8_noise0.1_negFalse.csv
#
# [20/224] Running: size=10, density=0.8, noise=0.1, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0034s
#   Saved: ResultsCSV/metrics_size10_density0.8_noise0.1_negTrue.csv
#
# [21/224] Running: size=10, density=0.8, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0034s
#   Saved: ResultsCSV/metrics_size10_density0.8_noise0.5_negFalse.csv
#
# [22/224] Running: size=10, density=0.8, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0016s
#   Saved: ResultsCSV/metrics_size10_density0.8_noise0.5_negTrue.csv
#
# [23/224] Running: size=10, density=0.8, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0036s
#   Saved: ResultsCSV/metrics_size10_density0.8_noise0.8_negFalse.csv
#
# [24/224] Running: size=10, density=0.8, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0016s
#   Saved: ResultsCSV/metrics_size10_density0.8_noise0.8_negTrue.csv
#
# [25/224] Running: size=10, density=1.0, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0002s | A*: 0.0033s
#   Saved: ResultsCSV/metrics_size10_density1.0_noise0.0_negFalse.csv
#
# [26/224] Running: size=10, density=1.0, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0011s | A*: 0.0033s
#   Saved: ResultsCSV/metrics_size10_density1.0_noise0.0_negTrue.csv
#
# [27/224] Running: size=10, density=1.0, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0003s | A*: 0.0034s
#   Saved: ResultsCSV/metrics_size10_density1.0_noise0.1_negFalse.csv
#
# [28/224] Running: size=10, density=1.0, noise=0.1, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0003s | A*: 0.0036s
#   Saved: ResultsCSV/metrics_size10_density1.0_noise0.1_negTrue.csv
#
# [29/224] Running: size=10, density=1.0, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0003s | A*: 0.0040s
#   Saved: ResultsCSV/metrics_size10_density1.0_noise0.5_negFalse.csv
#
# [30/224] Running: size=10, density=1.0, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0021s
#   Saved: ResultsCSV/metrics_size10_density1.0_noise0.5_negTrue.csv
#
# [31/224] Running: size=10, density=1.0, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0003s | A*: 0.0041s
#   Saved: ResultsCSV/metrics_size10_density1.0_noise0.8_negFalse.csv
#
# [32/224] Running: size=10, density=1.0, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0021s
#   Saved: ResultsCSV/metrics_size10_density1.0_noise0.8_negTrue.csv
#
# [33/224] Running: size=20, density=0.2, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0007s | A*: 0.0208s
#   Saved: ResultsCSV/metrics_size20_density0.2_noise0.0_negFalse.csv
#
# [34/224] Running: size=20, density=0.2, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0007s | A*: 0.0180s
#   Saved: ResultsCSV/metrics_size20_density0.2_noise0.0_negTrue.csv
#
# [35/224] Running: size=20, density=0.2, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0006s | A*: 0.0212s
#   Saved: ResultsCSV/metrics_size20_density0.2_noise0.1_negFalse.csv
#
# [36/224] Running: size=20, density=0.2, noise=0.1, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0006s | A*: 0.0221s
#   Saved: ResultsCSV/metrics_size20_density0.2_noise0.1_negTrue.csv
#
# [37/224] Running: size=20, density=0.2, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0007s | A*: 0.0228s
#   Saved: ResultsCSV/metrics_size20_density0.2_noise0.5_negFalse.csv
#
# [38/224] Running: size=20, density=0.2, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0077s
#   Saved: ResultsCSV/metrics_size20_density0.2_noise0.5_negTrue.csv
#
# [39/224] Running: size=20, density=0.2, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0006s | A*: 0.0235s
#   Saved: ResultsCSV/metrics_size20_density0.2_noise0.8_negFalse.csv
#
# [40/224] Running: size=20, density=0.2, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0076s
#   Saved: ResultsCSV/metrics_size20_density0.2_noise0.8_negTrue.csv
#
# [41/224] Running: size=20, density=0.5, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0010s | A*: 0.0204s
#   Saved: ResultsCSV/metrics_size20_density0.5_noise0.0_negFalse.csv
#
# [42/224] Running: size=20, density=0.5, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0010s | A*: 0.0223s
#   Saved: ResultsCSV/metrics_size20_density0.5_noise0.0_negTrue.csv
#
# [43/224] Running: size=20, density=0.5, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0010s | A*: 0.0233s
#   Saved: ResultsCSV/metrics_size20_density0.5_noise0.1_negFalse.csv
#
# [44/224] Running: size=20, density=0.5, noise=0.1, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0011s | A*: 0.0252s
#   Saved: ResultsCSV/metrics_size20_density0.5_noise0.1_negTrue.csv
#
# [45/224] Running: size=20, density=0.5, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0011s | A*: 0.0305s
#   Saved: ResultsCSV/metrics_size20_density0.5_noise0.5_negFalse.csv
#
# [46/224] Running: size=20, density=0.5, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0187s
#   Saved: ResultsCSV/metrics_size20_density0.5_noise0.5_negTrue.csv
#
# [47/224] Running: size=20, density=0.5, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0012s | A*: 0.0341s
#   Saved: ResultsCSV/metrics_size20_density0.5_noise0.8_negFalse.csv
#
# [48/224] Running: size=20, density=0.5, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0183s
#   Saved: ResultsCSV/metrics_size20_density0.5_noise0.8_negTrue.csv
#
# [49/224] Running: size=20, density=0.8, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0016s | A*: 0.0265s
#   Saved: ResultsCSV/metrics_size20_density0.8_noise0.0_negFalse.csv
#
# [50/224] Running: size=20, density=0.8, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0015s | A*: 0.0258s
#   Saved: ResultsCSV/metrics_size20_density0.8_noise0.0_negTrue.csv
#
# [51/224] Running: size=20, density=0.8, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0014s | A*: 0.0260s
#   Saved: ResultsCSV/metrics_size20_density0.8_noise0.1_negFalse.csv
#
# [52/224] Running: size=20, density=0.8, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0276s
#   Saved: ResultsCSV/metrics_size20_density0.8_noise0.1_negTrue.csv
#
# [53/224] Running: size=20, density=0.8, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0014s | A*: 0.0330s
#   Saved: ResultsCSV/metrics_size20_density0.8_noise0.5_negFalse.csv
#
# [54/224] Running: size=20, density=0.8, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0269s
#   Saved: ResultsCSV/metrics_size20_density0.8_noise0.5_negTrue.csv
#
# [55/224] Running: size=20, density=0.8, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0015s | A*: 0.0357s
#   Saved: ResultsCSV/metrics_size20_density0.8_noise0.8_negFalse.csv
#
# [56/224] Running: size=20, density=0.8, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0262s
#   Saved: ResultsCSV/metrics_size20_density0.8_noise0.8_negTrue.csv
#
# [57/224] Running: size=20, density=1.0, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0016s | A*: 0.0291s
#   Saved: ResultsCSV/metrics_size20_density1.0_noise0.0_negFalse.csv
#
# [58/224] Running: size=20, density=1.0, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0017s | A*: 0.0330s
#   Saved: ResultsCSV/metrics_size20_density1.0_noise0.0_negTrue.csv
#
# [59/224] Running: size=20, density=1.0, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0017s | A*: 0.0314s
#   Saved: ResultsCSV/metrics_size20_density1.0_noise0.1_negFalse.csv
#
# [60/224] Running: size=20, density=1.0, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0348s
#   Saved: ResultsCSV/metrics_size20_density1.0_noise0.1_negTrue.csv
#
# [61/224] Running: size=20, density=1.0, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0019s | A*: 0.0392s
#   Saved: ResultsCSV/metrics_size20_density1.0_noise0.5_negFalse.csv
#
# [62/224] Running: size=20, density=1.0, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0388s
#   Saved: ResultsCSV/metrics_size20_density1.0_noise0.5_negTrue.csv
#
# [63/224] Running: size=20, density=1.0, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0020s | A*: 0.0447s
#   Saved: ResultsCSV/metrics_size20_density1.0_noise0.8_negFalse.csv
#
# [64/224] Running: size=20, density=1.0, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.0385s
#   Saved: ResultsCSV/metrics_size20_density1.0_noise0.8_negTrue.csv
#
# [65/224] Running: size=50, density=0.2, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0084s | A*: 0.3897s
#   Saved: ResultsCSV/metrics_size50_density0.2_noise0.0_negFalse.csv
#
# [66/224] Running: size=50, density=0.2, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0083s | A*: 0.3653s
#   Saved: ResultsCSV/metrics_size50_density0.2_noise0.0_negTrue.csv
#
# [67/224] Running: size=50, density=0.2, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0074s | A*: 0.3726s
#   Saved: ResultsCSV/metrics_size50_density0.2_noise0.1_negFalse.csv
#
# [68/224] Running: size=50, density=0.2, noise=0.1, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0076s | A*: 0.3634s
#   Saved: ResultsCSV/metrics_size50_density0.2_noise0.1_negTrue.csv
#
# [69/224] Running: size=50, density=0.2, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0068s | A*: 0.4472s
#   Saved: ResultsCSV/metrics_size50_density0.2_noise0.5_negFalse.csv
#
# [70/224] Running: size=50, density=0.2, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.2777s
#   Saved: ResultsCSV/metrics_size50_density0.2_noise0.5_negTrue.csv
#
# [71/224] Running: size=50, density=0.2, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0066s | A*: 0.5121s
#   Saved: ResultsCSV/metrics_size50_density0.2_noise0.8_negFalse.csv
#
# [72/224] Running: size=50, density=0.2, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.2906s
#   Saved: ResultsCSV/metrics_size50_density0.2_noise0.8_negTrue.csv
#
# [73/224] Running: size=50, density=0.5, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0156s | A*: 0.3977s
#   Saved: ResultsCSV/metrics_size50_density0.5_noise0.0_negFalse.csv
#
# [74/224] Running: size=50, density=0.5, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0153s | A*: 0.3810s
#   Saved: ResultsCSV/metrics_size50_density0.5_noise0.0_negTrue.csv
#
# [75/224] Running: size=50, density=0.5, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0149s | A*: 0.5012s
#   Saved: ResultsCSV/metrics_size50_density0.5_noise0.1_negFalse.csv
#
# [76/224] Running: size=50, density=0.5, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.7100s
#   Saved: ResultsCSV/metrics_size50_density0.5_noise0.1_negTrue.csv
#
# [77/224] Running: size=50, density=0.5, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0148s | A*: 0.6001s
#   Saved: ResultsCSV/metrics_size50_density0.5_noise0.5_negFalse.csv
#
# [78/224] Running: size=50, density=0.5, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.6969s
#   Saved: ResultsCSV/metrics_size50_density0.5_noise0.5_negTrue.csv
#
# [79/224] Running: size=50, density=0.5, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0145s | A*: 0.6627s
#   Saved: ResultsCSV/metrics_size50_density0.5_noise0.8_negFalse.csv
#
# [80/224] Running: size=50, density=0.5, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 0.7218s
#   Saved: ResultsCSV/metrics_size50_density0.5_noise0.8_negTrue.csv
#
# [81/224] Running: size=50, density=0.8, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0213s | A*: 0.4328s
#   Saved: ResultsCSV/metrics_size50_density0.8_noise0.0_negFalse.csv
#
# [82/224] Running: size=50, density=0.8, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0221s | A*: 0.4450s
#   Saved: ResultsCSV/metrics_size50_density0.8_noise0.0_negTrue.csv
#
# [83/224] Running: size=50, density=0.8, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0228s | A*: 0.5693s
#   Saved: ResultsCSV/metrics_size50_density0.8_noise0.1_negFalse.csv
#
# [84/224] Running: size=50, density=0.8, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 1.0870s
#   Saved: ResultsCSV/metrics_size50_density0.8_noise0.1_negTrue.csv
#
# [85/224] Running: size=50, density=0.8, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0231s | A*: 0.7006s
#   Saved: ResultsCSV/metrics_size50_density0.8_noise0.5_negFalse.csv
#
# [86/224] Running: size=50, density=0.8, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 1.1303s
#   Saved: ResultsCSV/metrics_size50_density0.8_noise0.5_negTrue.csv
#
# [87/224] Running: size=50, density=0.8, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0220s | A*: 0.7814s
#   Saved: ResultsCSV/metrics_size50_density0.8_noise0.8_negFalse.csv
#
# [88/224] Running: size=50, density=0.8, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 1.1699s
#   Saved: ResultsCSV/metrics_size50_density0.8_noise0.8_negTrue.csv
#
# [89/224] Running: size=50, density=1.0, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0264s | A*: 0.4789s
#   Saved: ResultsCSV/metrics_size50_density1.0_noise0.0_negFalse.csv
#
# [90/224] Running: size=50, density=1.0, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0259s | A*: 0.4842s
#   Saved: ResultsCSV/metrics_size50_density1.0_noise0.0_negTrue.csv
#
# [91/224] Running: size=50, density=1.0, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0258s | A*: 0.5537s
#   Saved: ResultsCSV/metrics_size50_density1.0_noise0.1_negFalse.csv
#
# [92/224] Running: size=50, density=1.0, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 1.3069s
#   Saved: ResultsCSV/metrics_size50_density1.0_noise0.1_negTrue.csv
#
# [93/224] Running: size=50, density=1.0, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0261s | A*: 0.7015s
#   Saved: ResultsCSV/metrics_size50_density1.0_noise0.5_negFalse.csv
#
# [94/224] Running: size=50, density=1.0, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 1.2995s
#   Saved: ResultsCSV/metrics_size50_density1.0_noise0.5_negTrue.csv
#
# [95/224] Running: size=50, density=1.0, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0250s | A*: 0.7565s
#   Saved: ResultsCSV/metrics_size50_density1.0_noise0.8_negFalse.csv
#
# [96/224] Running: size=50, density=1.0, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 1.3445s
#   Saved: ResultsCSV/metrics_size50_density1.0_noise0.8_negTrue.csv
#
# [97/224] Running: size=100, density=0.2, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0491s | A*: 2.5278s
#   Saved: ResultsCSV/metrics_size100_density0.2_noise0.0_negFalse.csv
#
# [98/224] Running: size=100, density=0.2, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0496s | A*: 2.5226s
#   Saved: ResultsCSV/metrics_size100_density0.2_noise0.0_negTrue.csv
#
# [99/224] Running: size=100, density=0.2, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0490s | A*: 3.1562s
#   Saved: ResultsCSV/metrics_size100_density0.2_noise0.1_negFalse.csv
#
# [100/224] Running: size=100, density=0.2, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 4.2897s
#   Saved: ResultsCSV/metrics_size100_density0.2_noise0.1_negTrue.csv
#
# [101/224] Running: size=100, density=0.2, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0493s | A*: 4.2757s
#   Saved: ResultsCSV/metrics_size100_density0.2_noise0.5_negFalse.csv
#
# [102/224] Running: size=100, density=0.2, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 4.6308s
#   Saved: ResultsCSV/metrics_size100_density0.2_noise0.5_negTrue.csv
#
# [103/224] Running: size=100, density=0.2, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.0487s | A*: 4.7763s
#   Saved: ResultsCSV/metrics_size100_density0.2_noise0.8_negFalse.csv
#
# [104/224] Running: size=100, density=0.2, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 4.5227s
#   Saved: ResultsCSV/metrics_size100_density0.2_noise0.8_negTrue.csv
#
# [105/224] Running: size=100, density=0.5, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1047s | A*: 2.8583s
#   Saved: ResultsCSV/metrics_size100_density0.5_noise0.0_negFalse.csv
#
# [106/224] Running: size=100, density=0.5, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1023s | A*: 2.8467s
#   Saved: ResultsCSV/metrics_size100_density0.5_noise0.0_negTrue.csv
#
# [107/224] Running: size=100, density=0.5, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1036s | A*: 4.1023s
#   Saved: ResultsCSV/metrics_size100_density0.5_noise0.1_negFalse.csv
#
# [108/224] Running: size=100, density=0.5, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 10.4657s
#   Saved: ResultsCSV/metrics_size100_density0.5_noise0.1_negTrue.csv
#
# [109/224] Running: size=100, density=0.5, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1053s | A*: 5.4549s
#   Saved: ResultsCSV/metrics_size100_density0.5_noise0.5_negFalse.csv
#
# [110/224] Running: size=100, density=0.5, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 10.7948s
#   Saved: ResultsCSV/metrics_size100_density0.5_noise0.5_negTrue.csv
#
# [111/224] Running: size=100, density=0.5, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1032s | A*: 6.1452s
#   Saved: ResultsCSV/metrics_size100_density0.5_noise0.8_negFalse.csv
#
# [112/224] Running: size=100, density=0.5, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 11.0868s
#   Saved: ResultsCSV/metrics_size100_density0.5_noise0.8_negTrue.csv
#
# [113/224] Running: size=100, density=0.8, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1554s | A*: 3.3682s
#   Saved: ResultsCSV/metrics_size100_density0.8_noise0.0_negFalse.csv
#
# [114/224] Running: size=100, density=0.8, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1613s | A*: 3.5361s
#   Saved: ResultsCSV/metrics_size100_density0.8_noise0.0_negTrue.csv
#
# [115/224] Running: size=100, density=0.8, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1566s | A*: 4.5480s
#   Saved: ResultsCSV/metrics_size100_density0.8_noise0.1_negFalse.csv
#
# [116/224] Running: size=100, density=0.8, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 16.6434s
#   Saved: ResultsCSV/metrics_size100_density0.8_noise0.1_negTrue.csv
#
# [117/224] Running: size=100, density=0.8, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1559s | A*: 6.0840s
#   Saved: ResultsCSV/metrics_size100_density0.8_noise0.5_negFalse.csv
#
# [118/224] Running: size=100, density=0.8, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 17.4118s
#   Saved: ResultsCSV/metrics_size100_density0.8_noise0.5_negTrue.csv
#
# [119/224] Running: size=100, density=0.8, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1625s | A*: 6.9374s
#   Saved: ResultsCSV/metrics_size100_density0.8_noise0.8_negFalse.csv
#
# [120/224] Running: size=100, density=0.8, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 17.5161s
#   Saved: ResultsCSV/metrics_size100_density0.8_noise0.8_negTrue.csv
#
# [121/224] Running: size=100, density=1.0, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1893s | A*: 3.7402s
#   Saved: ResultsCSV/metrics_size100_density1.0_noise0.0_negFalse.csv
#
# [122/224] Running: size=100, density=1.0, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1942s | A*: 3.7424s
#   Saved: ResultsCSV/metrics_size100_density1.0_noise0.0_negTrue.csv
#
# [123/224] Running: size=100, density=1.0, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1916s | A*: 4.7143s
#   Saved: ResultsCSV/metrics_size100_density1.0_noise0.1_negFalse.csv
#
# [124/224] Running: size=100, density=1.0, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 20.7208s
#   Saved: ResultsCSV/metrics_size100_density1.0_noise0.1_negTrue.csv
#
# [125/224] Running: size=100, density=1.0, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1959s | A*: 6.3385s
#   Saved: ResultsCSV/metrics_size100_density1.0_noise0.5_negFalse.csv
#
# [126/224] Running: size=100, density=1.0, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 21.2019s
#   Saved: ResultsCSV/metrics_size100_density1.0_noise0.5_negTrue.csv
#
# [127/224] Running: size=100, density=1.0, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.1945s | A*: 7.2066s
#   Saved: ResultsCSV/metrics_size100_density1.0_noise0.8_negFalse.csv
#
# [128/224] Running: size=100, density=1.0, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 22.1758s
#   Saved: ResultsCSV/metrics_size100_density1.0_noise0.8_negTrue.csv
#
# [129/224] Running: size=200, density=0.2, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.3612s | A*: 21.0525s
#   Saved: ResultsCSV/metrics_size200_density0.2_noise0.0_negFalse.csv
#
# [130/224] Running: size=200, density=0.2, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.3707s | A*: 20.7015s
#   Saved: ResultsCSV/metrics_size200_density0.2_noise0.0_negTrue.csv
#
# [131/224] Running: size=200, density=0.2, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.3673s | A*: 30.3475s
#   Saved: ResultsCSV/metrics_size200_density0.2_noise0.1_negFalse.csv
#
# [132/224] Running: size=200, density=0.2, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 69.9743s
#   Saved: ResultsCSV/metrics_size200_density0.2_noise0.1_negTrue.csv
#
# [133/224] Running: size=200, density=0.2, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.3980s | A*: 42.4820s
#   Saved: ResultsCSV/metrics_size200_density0.2_noise0.5_negFalse.csv
#
# [134/224] Running: size=200, density=0.2, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 72.2208s
#   Saved: ResultsCSV/metrics_size200_density0.2_noise0.5_negTrue.csv
#
# [135/224] Running: size=200, density=0.2, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.3601s | A*: 47.2681s
#   Saved: ResultsCSV/metrics_size200_density0.2_noise0.8_negFalse.csv
#
# [136/224] Running: size=200, density=0.2, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 72.7663s
#   Saved: ResultsCSV/metrics_size200_density0.2_noise0.8_negTrue.csv
#
# [137/224] Running: size=200, density=0.5, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.8306s | A*: 24.4777s
#   Saved: ResultsCSV/metrics_size200_density0.5_noise0.0_negFalse.csv
#
# [138/224] Running: size=200, density=0.5, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.8257s | A*: 24.5966s
#   Saved: ResultsCSV/metrics_size200_density0.5_noise0.0_negTrue.csv
#
# [139/224] Running: size=200, density=0.5, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.8285s | A*: 39.4653s
#   Saved: ResultsCSV/metrics_size200_density0.5_noise0.1_negFalse.csv
#
# [140/224] Running: size=200, density=0.5, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 171.2001s
#   Saved: ResultsCSV/metrics_size200_density0.5_noise0.1_negTrue.csv
#
# [141/224] Running: size=200, density=0.5, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.8465s | A*: 53.5519s
#   Saved: ResultsCSV/metrics_size200_density0.5_noise0.5_negFalse.csv
#
# [142/224] Running: size=200, density=0.5, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 178.4530s
#   Saved: ResultsCSV/metrics_size200_density0.5_noise0.5_negTrue.csv
#
# [143/224] Running: size=200, density=0.5, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 0.8224s | A*: 61.1467s
#   Saved: ResultsCSV/metrics_size200_density0.5_noise0.8_negFalse.csv
#
# [144/224] Running: size=200, density=0.5, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 183.5385s
#   Saved: ResultsCSV/metrics_size200_density0.5_noise0.8_negTrue.csv
#
# [145/224] Running: size=200, density=0.8, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.2785s | A*: 29.0160s
#   Saved: ResultsCSV/metrics_size200_density0.8_noise0.0_negFalse.csv
#
# [146/224] Running: size=200, density=0.8, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.2824s | A*: 29.1002s
#   Saved: ResultsCSV/metrics_size200_density0.8_noise0.0_negTrue.csv
#
# [147/224] Running: size=200, density=0.8, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.2546s | A*: 42.9203s
#   Saved: ResultsCSV/metrics_size200_density0.8_noise0.1_negFalse.csv
#
# [148/224] Running: size=200, density=0.8, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 277.2869s
#   Saved: ResultsCSV/metrics_size200_density0.8_noise0.1_negTrue.csv
#
# [149/224] Running: size=200, density=0.8, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.2966s | A*: 59.6665s
#   Saved: ResultsCSV/metrics_size200_density0.8_noise0.5_negFalse.csv
#
# [150/224] Running: size=200, density=0.8, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 286.4859s
#   Saved: ResultsCSV/metrics_size200_density0.8_noise0.5_negTrue.csv
#
# [151/224] Running: size=200, density=0.8, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.2701s | A*: 67.5577s
#   Saved: ResultsCSV/metrics_size200_density0.8_noise0.8_negFalse.csv
#
# [152/224] Running: size=200, density=0.8, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 293.8273s
#   Saved: ResultsCSV/metrics_size200_density0.8_noise0.8_negTrue.csv
#
# [153/224] Running: size=200, density=1.0, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.5896s | A*: 32.0256s
#   Saved: ResultsCSV/metrics_size200_density1.0_noise0.0_negFalse.csv
#
# [154/224] Running: size=200, density=1.0, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.6142s | A*: 31.3609s
#   Saved: ResultsCSV/metrics_size200_density1.0_noise0.0_negTrue.csv
#
# [155/224] Running: size=200, density=1.0, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.6422s | A*: 43.9762s
#   Saved: ResultsCSV/metrics_size200_density1.0_noise0.1_negFalse.csv
#
# [156/224] Running: size=200, density=1.0, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 353.3019s
#   Saved: ResultsCSV/metrics_size200_density1.0_noise0.1_negTrue.csv
#
# [157/224] Running: size=200, density=1.0, noise=0.5, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.6019s | A*: 62.7225s
#   Saved: ResultsCSV/metrics_size200_density1.0_noise0.5_negFalse.csv
#
# [158/224] Running: size=200, density=1.0, noise=0.5, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 362.0171s
#   Saved: ResultsCSV/metrics_size200_density1.0_noise0.5_negTrue.csv
#
# [159/224] Running: size=200, density=1.0, noise=0.8, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 1.6189s | A*: 71.9164s
#   Saved: ResultsCSV/metrics_size200_density1.0_noise0.8_negFalse.csv
#
# [160/224] Running: size=200, density=1.0, noise=0.8, neg=True
#   Running Bellman-Ford (negative edges detected)...
#   Bellman-Ford: 370.4062s
#   Saved: ResultsCSV/metrics_size200_density1.0_noise0.8_negTrue.csv
#
# [161/224] Running: size=500, density=0.2, noise=0.0, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 6.0001s | A*: 358.2876s
#   Saved: ResultsCSV/metrics_size500_density0.2_noise0.0_negFalse.csv
#
# [162/224] Running: size=500, density=0.2, noise=0.0, neg=True
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 5.8242s | A*: 353.6121s
#   Saved: ResultsCSV/metrics_size500_density0.2_noise0.0_negTrue.csv
#
# [163/224] Running: size=500, density=0.2, noise=0.1, neg=False
#   Running Dijkstra...
#   Running A*...
#   Dijkstra: 6.0153s | A*: 642.7051s
#   Saved: ResultsCSV/metrics_size500_density0.2_noise0.1_negFalse.csv
#
# [164/224] Running: size=500, density=0.2, noise=0.1, neg=True
#   Running Bellman-Ford (negative edges detected)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 14
#      12                 current += 1
#      13                 print(f"[{current}/{total_configs}]", end=" ")
# ---> 14                 run_problem(size, density, noise_level, negative_values)
#      16 print("=" * 80)
#      17 print("Execution completed")
#
# Cell In[28], line 37, in run_problem(size, density, noise_level, negative_values, save_results)
#      35 print("  Running Bellman-Ford (negative edges detected)...")
#      36 start_time = time.time()
# ---> 37 bford_distances, bford_paths = all_pairs_bellman_ford(G)
#      38 bford_time = time.time() - start_time
#      40 dijkstra_distances, dijkstra_paths = None, None
#
# Cell In[27], line 50, in all_pairs_bellman_ford(graph)
#      47 all_distances = []
#      49 for source in graph.nodes:
# ---> 50     distances, predecessors = bellman_ford(graph, source)
#      52     if distances is None:
#      53         source_paths = {target: None for target in graph.nodes}
#
# Cell In[26], line 9, in bellman_ford(graph, start)
#       7 for _ in range(len(graph.nodes) - 1):
#       8     for u, v in graph.edges():
# ----> 9         weight = graph[u][v].get('weight', 1)
#      10         if distances[u] + weight < distances[v]:
#      11             distances[v] = distances[u] + weight
#
# File ~\AppData\Roaming\Python\Python313\site-packages\networkx\classes\graph.py:522, in Graph.__getitem__(self, n)
#     498 def __getitem__(self, n):
#     499     """Returns a dict of neighbors of node n.  Use: 'G[n]'.
#     500
#     501     Parameters
#    (...)    520     AtlasView({1: {}})
#     521     """
# --> 522     return self.adj[n]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\networkx\classes\coreviews.py:82, in AdjacencyView.__getitem__(self, name)
#      81 def __getitem__(self, name):
# ---> 82     return AtlasView(self._atlas[name])
#
# KeyboardInterrupt:
